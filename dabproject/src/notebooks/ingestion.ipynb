# %%
# %sql
select * from swati_catalog.bronze.dim_account

# %%
dbutils.widgets.text("catalog_name","")

# %%
catalog_name=dbutils.widgets.get("catalog_name")

# %%
df=spark.sql(f"Select * from {catalog_name}.bronze.bank_bronze")

# %%
df.display()
